# %%
##### matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
## Line plot

# %%
plt.title("Plot")
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# Anaconda prompt에서 plt.show()까지 입력해도 그래프 그려짐
# 단, 그림 창을 닫기 전까지는 다른 것 작동이 안 됨

# %%
## 한글 폰트 사용

# %%
plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

## 한글 글씨 깨짐
# Out:
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Playdata\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 시스템 폰트 경로 리스트 - 외우지 말고 필요할 때 호출
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\Windows\\Fonts\\BOD_BLAR.TTF', 'C:\\Windows\\Fonts\\LSANS.TTF', 'C:\\Windows\\Fonts\\TEMPSITC.TTF', 'C:\\Windows\\Fonts\\STSONG.TTF', 'C:\\Windows\\Fonts\\FREESCPT.TTF', 'C:\\Windows\\Fonts\\PERTIBD.TTF', 'C:\\Windows\\Fonts\\CALIST.TTF', 'C:\\Windows\\Fonts\\tahomabd.ttf', 'C:\\Windows\\Fonts\\NGULIM.TTF', 'C:\\Windows\\Fonts\\LCALLIG.TTF', 'C:\\Windows\\Fonts\\LFAXD.TTF', 'C:\\Windows\\Fonts\\HMFMOLD.TTF', 'C:\\Windows\\Fonts\\georgiaz.ttf', 'C:\\Windows\\Fonts\\CENTURY.TTF', 'C:\\Windows\\Fonts\\BSSYM7.TTF', 'C:\\Windows\\Fonts\\FELIXTI.TTF', 'C:\\Windows\\Fonts\\trebucbi.ttf', 'C:\\Windows\\Fonts\\Candarali.ttf', 'C:\\Windows\\Fonts\\BRUSHSCI.TTF', 'C:\\Windows\\Fonts\\SCRIPTBL.TTF', 'C:\\Windows\\Fonts\\GARABD.TTF', 'C:\\Windows\\Fonts\\LeelUIsl.ttf', 'C:\\Windows\\Fonts\\HTOWERTI.TTF', 'C:\\Windows\\Fonts\\malgun.ttf', 'C:\\Windows\\Fonts\\BOOKOS.TTF', 'C:\\Windows\\Fonts\\FRAHVIT.TTF', 'C:\\Windows\\Fonts\\GILBI___.TTF', 'C:\\Windows\\Fonts\\YuGothR.ttc', 'C:\\Windows\\F
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname = '원하는 폰트 경로')  # fname = "입력"
plt.rcParams['font.family'] = prop.get_family()

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
# 외부 폰트 사용
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./Fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumSquareOTF
# NanumSquareOTF_ac
# NanumGothic Eco
# NanumMyeongjoOTF Eco
# NanumSquareRoundOTF
# NanumSquare_ac
# NanumGothic
# NanumGothic
# NanumSquareOTF
# NanumSquare Neo OTF ExtraBold
# NanumBarunGothicOTF
# NanumSquare Neo ExtraBold
# NanumSquareRound
# D2Coding
# Nanum Pen Script
# NanumSquare Neo OTF Regular
# NanumMyeongjoOTF Eco
# NanumBarunGothic YetHangul
# NanumGothicOTF
# NanumBarunGothic
# NanumBarunGothic
# NanumSquare_ac
# NanumSquare Neo Regular
# NanumSquare_ac
# NanumMyeongjo YetHangul
# D2Coding ligature
# NanumBarunpenOTF
# NanumGothic
# Nanum Brush Script
# NanumSquareRound
# NanumBarunGothicOTF YetHangul
# NanumSquareRoundOTF
# NanumSquare Neo OTF Heavy
# NanumMyeongjo
# NanumSquare Neo Bold
# NanumSquareRoundOTF
# NanumSquareOTF
# NanumMyeongjo
# NanumMyeongjo Eco
# NanumSquareRoundOTF
# NanumBarunGothic
# NanumMyeongjo Eco
# NanumBarunpen
# NanumGothic
# NanumMyeongjoOTF
# NanumBarunpen
# NanumGothicOTF Eco
# NanumGothicOTF Eco
# ...

# %%
# Set font family globally - 전체 범위에 대해(globally) 적용
mpl.rcParams['font.family'] = 'NanumGothic'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
plt.title("한글")
plt.plot(range(1, 5))
plt.show()

# %%
global_font = {"family": "NanumGothic", "size": 12, "weight": "bold"}

mpl.rc("font", **global_font)

# **을 사용하면 mpl.rc('font', 'family': 'NanumGothic', 'size': 14, 'weight': 'bold')와 동일
# 딕셔너리 형태의 Key: Value가 저장된 객체(여기서는 global_font)를 그대로 받아옴

# %%
plt.title("한글 제목")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("x축 레이블")
plt.ylabel("y축 레이블")
plt.show()

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
title_font = {"family": "NanumMyeongjo", "size": 24, "color": "black"}
xlabel_font = {"family": "NanumBarunpen", "size": 18, "weight": "bold", "color": "darkred"}
ylabel_font = {"family": "NanumBarunGothic", "size": 12, "weight": "light", "color": "blue"}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title("한글 제목", fontdict = title_font)
plt.xlabel("x축 레이블", fontdict = xlabel_font)
plt.ylabel("y축 레이블", fontdict = ylabel_font)
plt.show()

# %%
# 음수 부호 설정
mpl.rc("axes", unicode_minus = False)  # ASCII 코드의 hyphen으로 입력 -> 안 깨짐

# mpl.rcParms() = False

# %%
## Style 설정

# %%
plt.title("Default 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
plt.title("'re--' 스타일의 plot")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rp--')
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = 'b', lw = 5, ls = "--", marker = "o", ms = 15, mec = "g",
         mew = 5, mfc = "r")

plt.title("스타일 적용 예")
plt.show()

# %%
## 축 범위 설정 - xlim, ylim

# %%
plt.title("x축, y축의 범위 설정")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c = 'b', lw = 5, ls = "--", marker = "o", ms = 15, mec = "g",
         mew = 5, mfc = "r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %%
## 틱(tick) 설정

# %%
import numpy as np

X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)

plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)

plt.title("TeX, 문자열로 tick label 정의")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %%
## 여러 개의 선그래프 그리기

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여려 개의 선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현")
style1 = {"c": "b", "lw": 5, "ls": "--", "marker" : "o", "ms": 15, "mec": "g", "mew": 15, "mfc": "r"}
style2 = {"c": "k", "lw": 3, "ls": ":", "marker" : "s", "ms": 10, "mec": "m", "mew": 5, "mfc": "c"}

plt.plot([1, 4, 9, 16], **style1)
plt.plot([9, 16, 4, 1], **style2)

plt.show()

# %%
## 범례 (Legend)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)

plt.title("Legend를 표시한 Plot")
plt.plot(X, C, ls = "--", label = "cosine")
plt.plot(X, S, ls = ":", label = "sine")
plt.legend(loc = 2)  # 범례의 위치 지정. loc = 2 = upper left
plt.show()

# %%
# X, Y축

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label = "cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
# Q1.
x = np.arange(32, 101)
plt.plot(x, (x - 32)*(5/9), c = 'coral', lw = 2, ls = "-.")

plt.title("섭씨 온도와 화씨 온도")
plt.xlim(30, 105)
plt.ylim(0, 39)
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")

plt.xlabel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14064\2683689675.py in <module>
#       9 plt.ylabel("섭씨 온도")
#      10
# ---> 11 plt.xlabel()
#
# TypeError: xlabel() missing 1 required positional argument: 'xlabel'

# %%
# Q1 풀이
x = np.arange(32, 100)
y = (x - 32) * (5 / 9)

import matplotlib as mlp
mlp.rcParams["font.family"] = "NanumGothic"
mlp.rcParams["axes.unicode_minus"] = False

plt.title("섭씨 온도와 화씨 온도")
plt.xlabel("화씨 온도")
plt.ylabel("섭씨 온도")
plt.plot(x, y, "r-.")
plt.show()

# xlim, ylim은 굳이 지정하지 않아도 알아서 그려줌

# %%
## Figure & Axes

# %%
# Figure가 행렬이라면 Axes는 행렬의 원소로 생각할 수 있음

# %%
# subplots()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)

# %%
np.random.seed(0)
fl = plt.figure(figsize = (10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)

f1 = plt.figure(1)
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], "ro:")

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))

plt.show()
# Out:
# Figure(640x480) 1950088315136
# Figure(640x480) 1950088315136

# %%
# Q. x축, y축 글씨 크기 조정? (일시적으로 말고)

# %%
# subplot()

# %%
ax1 = plt.subplot(2, 1, 1)
ax2 = plt.subplot(2, 1, 2)

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, "yo-")
plt.title("A tale of 2 subplots")
plt.ylabel("Damped oscillation")

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, "r.-")
plt.xlabel("time (s)")
plt.ylabel("Undamped")

plt.tight_layout()

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()  # 그래프 간 간격 알아서 조정해주는 역할
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axis 1")

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axis 2")

axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axis 3")

axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axis 4")

plt.tight_layout()
plt.show()

# %%
## Axis (축)

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()  # y축 2개 생성됨

ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], "r-", label = "y0")
ax0.set_ylabel("y0")
ax0.grid(False)

ax1.plot([100, 200, 220, 180, 120], "g:", label = "y1")
ax1.set_ylabel("y1")
ax1.grid(False)

ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
##### Bar chart

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [2, 3, 1]
x = ["가", "나", "다"]
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# 가로 방향

# %%
y = [2, 3, 1]
x = ["가", "나", "다"]
plt.title("Bar Chart")
plt.barh(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# 색 채우기

# %%
x = ["가", "나", "다"]
y = [2, 3, 1]
colors = ["red", "green", "blue"]

plt.title("Bar Chart")
plt.bar(x, y, color = colors)  # 색 채우기
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# 에러 바 (Error bar)

# %%
np.random.seed(0)

people = ["몽룡", "춘향", "방자", "향단"]
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr = error, alpha = 0.4)  # alpha는 색 진하기
plt.xlabel("x 레이블")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Q2.
import seaborn as sns
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.alive.value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
alive = sum(titanic.alive == "yes")
dead = len(titanic) - alive
colors = ["red", "green"]

y = [dead, alive]
x = ["사망자", "생존자"]
plt.title("타이타닉호 생존 여부")
plt.barh(x, y, color = colors)
plt.xlabel("인원 수")
plt.show()

# %%
# Q2 풀이
bar_chart = titanic["alive"].value_counts()
bar_chart.rename({"no": "사망자", "yes": "생존자"}, inplace = True)
bar_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
alive = bar_chart.index
value = bar_chart.values
bar_colors = ["red", "green"]

plt.title("타이타닉호 생존 여부")
plt.barh(alive, value, color = bar_colors)
plt.xlabel("인원 수")
plt.show()

# %%
## 파이 차트 (Pie Chart)

# %%
labels = ["월세", "전세", "자가", "기타"]
sizes = [15, 30, 45, 10]
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral"]
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode = explode, labels = labels, colors = colors, autopct = "%1.1f%%", shadow = True, startangle = 90)
plt.axis("equal")
plt.show()

# %%
# Q3.
bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

# %%
import pandas as pd

a = titanic.age.dropna()

bins = [0, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "장년", "중년", "노년"]
explode = (0.1, 0, 0, 0, 0)
colors = ["yellowgreen", "gold", "lightskyblue", "lightcoral", "orange"]

size = pd.cut(a, bins = bins, labels = labels).value_counts(True)
size
# Out:
# 장년      0.337535
# 청년      0.322129
# 미성년자    0.250700
# 중년      0.082633
# 노년      0.007003
# Name: age, dtype: float64

# %%
plt.pie(size, explode = explode, labels = size.index, colors = colors, autopct = "%1.1f%%", shadow = True, startangle = 90)
plt.axis("equal")
plt.show()

# %%
## 히스토그램 (Histogram)

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins = 10)
plt.show()

# %%
arrays  # y축 경곗값
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins  # x축 경곗값
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %%
## Scatter Plot

# %%
np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c = y2, s = y3)
plt.show()

# %%
## imshow - 행렬 형태의 2차원 데이터

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits: 0")
plt.imshow(X, interpolation = "nearest", cmap = plt.cm.bone_r)  # cmap = color map, 색깔 조정
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left = 0.35, right = 0.65, bottom = 0.35, top = 0.65)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14064\2331461083.py in <module>
#       3 plt.xticks([])
#       4 plt.yticks([])
# ----> 5 plt.grid(False)
#       6 plt.subplots_adjust(left = 0.35, right = 0.65, bottom = 0.35, top = 0.65)
#       7 plt.show()
#
# TypeError: 'bool' object is not callable

# %%
dir(plt.cm)[:10]  # 앞 10개의 색깔 조회 가능. cm = color map
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
fig, axes = plt.subplots(1, 4, figsize = (12, 3), subplot_kw = {"xticks": [], "yticks": []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation = "nearest", cmap = plt.cm.Blues)

axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation = "nearest", cmap = plt.cm.Blues_r)

axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation = "nearest", cmap = "BrBG")

axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation = "nearest", cmap = "BrBG_r")

plt.show()

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}

fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
## 컨투어 플롯 (Contour Plot)

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y **2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha = .75, cmap = "jet")
plt.contour(XX, YY, ZZ, colors = "black")
plt.show()

# %%
## 3D 서피스 플롯 (Surface Plot)

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(XX, YY, ZZ, rstride = 1, cstride = 1, cmap = "hot")
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_14064\373702868.py:9: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
