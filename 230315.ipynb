# %% [markdown]
# ## Setting

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams['font.family'] = 'NanumGothic'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
mpl.rc("axes", unicode_minus = False)

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_theme(style = "whitegrid")

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
survey_raw_df = pd.read_csv("datas/survey_results_public.csv", index_col = "ResponseId")
survey_raw_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
schema_raw = pd.read_csv("datas/survey_results_schema.csv", index_col  = "qname")["question"]
schema_raw
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# S1             <span style="font-size:22px; font-family: aria...
# MainBranch     Which of the following options best describes ...
# Employment     Which of the following best describes your cur...
#                                      ...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# TrueFalse_1    Are you involved in supporting new hires durin...
# TrueFalse_2    Do you use learning resources provided by your...
# TrueFalse_3    Does your employer give you time to learn new ...
# Name: question, Length: 79, dtype: object

# %%
survey_raw_df.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
schema_raw.index
# Out:
# Index(['S0', 'MetaInfo', 'S1', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'S2', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'S3', 'Language', 'Database', 'Platform',
#        'Webframe', 'MiscTech', 'ToolsTech', 'NEWCollabTools', 'OpSys',
#        'VersionControlSystem', 'VCInteraction', 'VCHosting',
#        'OfficeStackAsync', 'OfficeStackSync', 'Blockchain', 'S4', 'NEWSOSites',
#        'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm', 'S5', 'Age',
#        'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility',
#        'MentalHealth', 'S6', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge',
#        'Frequency', 'TimeSearching', 'TimeAnswering', 'Onboarding',
#        'ProfessionalTech', 'SOTeamsUsage', 'TrueFalse', 'S7', 'SurveyLength',
# ...

# %% [markdown]
# 두 결과가 완벽히 일치하지는 않아도 비슷함을 알 수 있음

# %%
schema_raw["CompTotal"]  # 질문 내용
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
schema_raw["CompFreq"]
# Out:
# 'Is that compensation weekly, monthly, or yearly?'

# %%
survey_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 78 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   MainBranch                      73268 non-null  object
#  1   Employment                      71709 non-null  object
#  2   RemoteWork                      58958 non-null  object
#  3   CodingActivities                58899 non-null  object
#  4   EdLevel                         71571 non-null  object
#  5   LearnCode                       71580 non-null  object
#  6   LearnCodeOnline                 50685 non-null  object
#  7   LearnCodeCoursesCert            29389 non-null  object
#  8   YearsCode                       71331 non-null  object
#  9   YearsCodePro                    51833 non-null  object
#  10  DevType                         61302 non-null  object
#  11  OrgSize                         51039 non-null  object
# ...

# %%
## columns, rows의 개수가 많을 때 한 번에 볼 수 있는 크기 조정

# %%
pd.set_option("display.max_columns", 78)

# %%
pd.set_option("display.max_rows", 78)
# schema에 대한 결과를 한번에 보기 위해 조정하는 것

# %%
survey_raw_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
selected_columns = ["Country", "Age", "Gender", "EdLevel",  # 인구 통계
                    "YearsCode", "YearsCodePro", "LanguageHaveWorkedWith", "LanguageWantToWorkWith",
                    "LearnCodeCoursesCert", "ProfessionalTech", "SOAccount",  # 프로그래밍 경험
                    "Employment", "DevType", "WorkExp"]  # 고용 관련 정보

# %%
survey_df = survey_raw_df[selected_columns].copy()
survey_df
# Out:
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
# ...                                                       ...
# 73264                                                 Nigeria
# 73265                                United States of America
# 73266                                United States of America
# 73267       United Kingdom of Great Britain and Northern I...
# 73268                                                  Canada
#
#                         Age Gender  \
# ResponseId
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3           25-34 years old    Man
# 4           35-44 years old    Man
# ...

# %%
survey_df.info()  # 자료형이 왜 전부 object일까?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73268 entries, 1 to 73268
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 71771 non-null  object
#  1   Age                     70946 non-null  object
#  2   Gender                  70853 non-null  object
#  3   EdLevel                 71571 non-null  object
#  4   YearsCode               71331 non-null  object
#  5   YearsCodePro            51833 non-null  object
#  6   LanguageHaveWorkedWith  70975 non-null  object
#  7   LanguageWantToWorkWith  67027 non-null  object
#  8   LearnCodeCoursesCert    29389 non-null  object
#  9   ProfessionalTech        34906 non-null  object
#  10  SOAccount               71572 non-null  object
#  11  Employment              71709 non-null  object
#  12  DevType                 61302 non-null  object
#  13  WorkExp                 36769 non-null  float64
# ...

# %%
print(schema_raw["YearsCode"])
# Out:
# Including any education, how many years have you been coding in total?

# %%
survey_df["YearsCode"].value_counts()
# Out:
# 10                    5217
# 5                     5193
# 6                     4651
# 4                     4480
# 7                     4237
# 8                     4227
# 3                     4122
# 2                     3351
# 12                    2995
# 15                    2962
# 20                    2659
# 9                     2581
# 11                    1819
# 14                    1811
# 13                    1624
# 25                    1582
# 1                     1566
# Less than 1 year      1413
# 16                    1406
# 30                    1330
# 22                    1176
# 18                    1150
# 17                    1080
# 40                     777
# 24                     752
# 35                     742
# 23                     644
# 19                     563
# 26                     489
# 27                     485
# 21                     483
# 28                     425
# 32                     371
# 38                     288
# ...

# %%
survey_df["YearsCode"]
# Out:
# ResponseId
# 1        NaN
# 2        NaN
# 3         14
# 4         20
# 5          8
#         ...
# 73264      8
# 73265      6
# 73266     42
# 73267     50
# 73268     16
# Name: YearsCode, Length: 73268, dtype: object

# %%
# Q1. 특정 Columns이 갖는 NaN 값 확인하는 함수 만들기
def count_nan(Series):
    return Series.isnull().sum()

count_nan(survey_df["YearsCode"])
# Out:
# 1937

# %%
# Q1 다른 풀이
def count_nan(series):
    return len(series) - series.count()

count_nan(survey_df["YearsCode"])
# Out:
# 1937

# %%
# Q2.
survey_df["YearsCode"].replace("Less than 1 year", 0, inplace = True)
survey_df["YearsCode"].replace("More than 50 years", 51, inplace = True)

# %%
survey_df["YearsCode"] = survey_df["YearsCode"].astype("float")  # .astype(float)도 실행됨
survey_df["YearsCode"]
# Out:
# ResponseId
# 1         NaN
# 2         NaN
# 3        14.0
# 4        20.0
# 5         8.0
#          ...
# 73264     8.0
# 73265     6.0
# 73266    42.0
# 73267    50.0
# 73268    16.0
# Name: YearsCode, Length: 73268, dtype: float64

# %%
print(schema_raw["YearsCodePro"])
# Out:
# NOT including education, how many years have you coded professionally (as a part of your work)?

# %%
count_nan(survey_df["YearsCodePro"])
# Out:
# 21435

# %%
survey_df["YearsCodePro"].value_counts()
# Out:
# 3                     4261
# 5                     4057
# 2                     3945
# 4                     3884
# 10                    3333
# 6                     3184
# 7                     2760
# 8                     2646
# 1                     2644
# Less than 1 year      1972
# 15                    1822
# 12                    1711
# 9                     1583
# 20                    1472
# 11                    1369
# 14                    1048
# 22                     933
# 16                     921
# 13                     914
# 25                     877
# 18                     787
# 17                     723
# 30                     568
# 23                     463
# 24                     454
# 21                     429
# 19                     380
# 26                     320
# 27                     286
# 35                     266
# 28                     254
# 32                     223
# 40                     175
# 29                     126
# ...

# %%
# Q3.
survey_df["YearsCodePro"].replace("Less than 1 year", 0, inplace = True)
survey_df["YearsCodePro"].replace("More than 50 years", 51, inplace = True)
survey_df["YearsCodePro"] = survey_df["YearsCodePro"].astype(float)
survey_df["YearsCodePro"]
# Out:
# ResponseId
# 1         NaN
# 2         NaN
# 3         5.0
# 4        17.0
# 5         3.0
#          ...
# 73264     5.0
# 73265     5.0
# 73266    33.0
# 73267    31.0
# 73268     5.0
# Name: YearsCodePro, Length: 73268, dtype: float64

# %%
survey_df.describe()
# Out:
#           YearsCode  YearsCodePro       WorkExp
# count  71331.000000  51833.000000  36769.000000
# mean      12.251307      9.910270     10.242378
# std        9.952419      8.712048      8.706850
# min        0.000000      0.000000      0.000000
# 25%        5.000000      4.000000      4.000000
# 50%        9.000000      7.000000      8.000000
# 75%       16.000000     14.000000     15.000000
# max       51.000000     51.000000     50.000000

# %%
survey_df2 = survey_raw_df[selected_columns].copy()
survey_df2.head()
# Out:
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
#
#                         Age Gender  \
# ResponseId
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3           25-34 years old    Man
# 4           35-44 years old    Man
# 5           25-34 years old    NaN
#
#                                                     EdLevel YearsCode  \
# ResponseId
# 1                                                       NaN       NaN
# 2                                                       NaN       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)        14
# ...

# %%
survey_df2["YearsCode"] = pd.to_numeric(survey_df.YearsCode, errors = "coerce")
survey_df2["YearsCodePro"] = pd.to_numeric(survey_df.YearsCodePro, errors = "coerce")

# pd.to_numeric() 메서드에서 error 값을 "coerce"로 하면 숫자로 바꿀 수 없는 값을 NaN으로 처리함

# %%
survey_df2["YearsCode"]
# Out:
# ResponseId
# 1         NaN
# 2         NaN
# 3        14.0
# 4        20.0
# 5         8.0
#          ...
# 73264     8.0
# 73265     6.0
# 73266    42.0
# 73267    50.0
# 73268    16.0
# Name: YearsCode, Length: 73268, dtype: float64

# %%
schema_raw["Gender"]
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
survey_df["Gender"].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# ...

# %% [markdown]
# 세미콜론(;)을 구분자로 저장된 데이터

# %%
survey_df["Gender"].str  # StringMethods

# %%
survey_df["Gender"].str.contains(";")  # ;이 포함된 값들을 False로 변환
# Out:
# ResponseId
# 1          NaN
# 2          NaN
# 3        False
# 4        False
# 5          NaN
#          ...
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# 73268    False
# Name: Gender, Length: 73268, dtype: object

# %%
survey_df["Gender"].str.contains(";", na = False)  # NaN이 False로 바뀜

# dtype도 object에서 bool로도 바뀜
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 73264    False
# 73265    False
# 73266    False
# 73267    False
# 73268    False
# Name: Gender, Length: 73268, dtype: bool

# %%
survey_df.where(~(survey_df["Gender"].str.contains(";", na = False)))
# Out:
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
# ...                                                       ...
# 73264                                                 Nigeria
# 73265                                United States of America
# 73266                                United States of America
# 73267       United Kingdom of Great Britain and Northern I...
# 73268                                                  Canada
#
#                         Age Gender  \
# ResponseId
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3           25-34 years old    Man
# 4           35-44 years old    Man
# ...

# %%
survey_df.where(~(survey_df["Gender"].str.contains(";", na = False)), np.nan, inplace = True)
survey_df
# Out:
#                                                       Country  \
# ResponseId
# 1                                                         NaN
# 2                                                      Canada
# 3           United Kingdom of Great Britain and Northern I...
# 4                                                      Israel
# 5                                    United States of America
# ...                                                       ...
# 73264                                                 Nigeria
# 73265                                United States of America
# 73266                                United States of America
# 73267       United Kingdom of Great Britain and Northern I...
# 73268                                                  Canada
#
#                         Age Gender  \
# ResponseId
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3           25-34 years old    Man
# 4           35-44 years old    Man
# ...

# %%
survey_df["Gender"].value_counts()  # 성별 전처리 완료
# Out:
# Man                                                  64607
# Woman                                                 3399
# Prefer not to say                                     1172
# Non-binary, genderqueer, or gender non-conforming      704
# Or, in your own words:                                 279
# Name: Gender, dtype: int64

# %%
# %matplotlib inline
# jupyter에서만 쓸 수 있는 매직 명령어

sns.set_style("darkgrid")
mpl.rcParams["font.size"] = 14
mpl.rcParams["figure.figsize"] = (9, 5)
mpl.rcParams["figure.facecolor"] = "#00000000"  # 검은색. 숫자가 작을수록 검은색에 가까워짐
                                             # 2자리씩 Red, Green, Blue값 지정 가능

# %%
# mpl.rcParams["axes.facecolor"] = "원하는 색"

# %%
print(plt.style.available)  # 심미적 요소 설정
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# matplotlib.pyplot에 style을 적용할 수 있는 것에 대한 리스트 조회

# %% [markdown]
# .use() 메서드에 plt.style.available 속성으로 얻은 리스트의 요소를 넣어주면 해당 스타일이 적용됨
# .use() 메서드에 'default'를 넣어주면 기본 속성으로 돌아감

# %%
plt.style.use("default")

# %%
plt.style.use("seaborn-dark")

# %%
plt.plot(range(10))
plt.show()

# %%
schema_raw["Country"]
# Out:
# 'Where do you live? <span style="font-weight: bolder;">*</span>'

# %%
survey_df["Country"].unique()
# Out:
# array([nan, 'Canada',
#        'United Kingdom of Great Britain and Northern Ireland', 'Israel',
#        'United States of America', 'Germany', 'India', 'Netherlands',
#        'Croatia', 'Australia', 'Russian Federation', 'Czech Republic',
#        'Austria', 'Serbia', 'Italy', 'Ireland', 'Poland', 'Slovenia',
#        'Iraq', 'Sweden', 'Madagascar', 'Norway', 'Taiwan',
#        'Hong Kong (S.A.R.)', 'Mexico', 'France', 'Brazil', 'Lithuania',
#        'Uruguay', 'Denmark', 'Spain', 'Egypt', 'Turkey', 'South Africa',
#        'Ukraine', 'Finland', 'Romania', 'Portugal', 'Singapore', 'Oman',
#        'Belgium', 'Chile', 'Bulgaria', 'Latvia', 'Philippines', 'Greece',
#        'Belarus', 'Saudi Arabia', 'Kenya', 'Switzerland', 'Iceland',
#        'Viet Nam', 'Thailand', 'China', 'Montenegro', 'Slovakia', 'Japan',
#        'Luxembourg', 'Turkmenistan', 'Argentina', 'Hungary', 'Tunisia',
#        'Bangladesh', 'Maldives', 'Dominican Republic', 'Jordan',
# ...

# %%
survey_df["Country"].nunique()
# Out:
# 180

# %%
# Q4.
survey_df["Country"].value_counts().nlargest(15)
# Out:
# United States of America                                13321
# India                                                    6618
# Germany                                                  5342
# United Kingdom of Great Britain and Northern Ireland     4132
# Canada                                                   2459
# France                                                   2306
# Brazil                                                   2088
# Poland                                                   1719
# Netherlands                                              1539
# Spain                                                    1511
# Italy                                                    1504
# Australia                                                1449
# Russian Federation                                       1215
# Turkey                                                   1014
# Sweden                                                   1008
# Name: Country, dtype: int64

# %%
# Q4 다른 풀이
top_countries = survey_df["Country"].value_counts().head(15)  # Doc string에도 결과 같다고 나와있음
top_countries
# Out:
# United States of America                                13321
# India                                                    6618
# Germany                                                  5342
# United Kingdom of Great Britain and Northern Ireland     4132
# Canada                                                   2459
# France                                                   2306
# Brazil                                                   2088
# Poland                                                   1719
# Netherlands                                              1539
# Spain                                                    1511
# Italy                                                    1504
# Australia                                                1449
# Russian Federation                                       1215
# Turkey                                                   1014
# Sweden                                                   1008
# Name: Country, dtype: int64

# %%
import seaborn as sns
mpl.rc("axes", unicode_minus = False)
mpl.rcParams['font.family'] = 'NanumGothic'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
# Q5.
sns.barplot(x = top_countries.index, y = top_countries)
plt.title("응답자의 지역")
plt.ylabel("응답자의 수")
plt.xticks(rotation = 90)
plt.show()

# %%
top_countries.index
# Out:
# Index(['United States of America', 'India', 'Germany',
#        'United Kingdom of Great Britain and Northern Ireland', 'Canada',
#        'France', 'Brazil', 'Poland', 'Netherlands', 'Spain', 'Italy',
#        'Australia', 'Russian Federation', 'Turkey', 'Sweden'],
#       dtype='object')

# %%
schema_raw["Age"]
# Out:
# 'What is your age?'

# %%
age_counts = survey_df["Age"].value_counts()
age_counts
# Out:
# 25-34 years old       27878
# 18-24 years old       16455
# 35-44 years old       13866
# 45-54 years old        5250
# Under 18 years old     3775
# 55-64 years old        1974
# 65 years or older       547
# Prefer not to say       512
# Name: Age, dtype: int64

# %%
survey_df["Age"].unique()
# Out:
# array([nan, '25-34 years old', '35-44 years old', 'Under 18 years old',
#        '18-24 years old', '45-54 years old', '55-64 years old',
#        '65 years or older', 'Prefer not to say'], dtype=object)

# %%
survey_df["Age"].nunique()
# Out:
# 8

# %%
# Q6.
age = ['Under 18 years old', '18-24 years old', '25-34 years old', '35-44 years old', '45-54 years old',
       '55-64 years old', '65 years or older', 'Prefer not to say']

# %%
plt.figure(figsize = (12, 6))
plt.title(schema_raw["Age"])
plt.xticks(rotation = 90)
sns.barplot(x = age_counts.index, y = age_counts.values, order = age)

plt.xlabel("나이")
plt.ylabel("응답자의 수")
plt.show()

# %%
schema_raw["Age"]
# Out:
# 'What is your age?'

# %%
schema_raw.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply.'

# %%
gender_counts = survey_df["Gender"].value_counts(True)
gender_counts
# Out:
# Man                                                  0.920839
# Woman                                                0.048446
# Prefer not to say                                    0.016704
# Non-binary, genderqueer, or gender non-conforming    0.010034
# Or, in your own words:                               0.003977
# Name: Gender, dtype: float64

# %%
gender_counts.index
# Out:
# Index(['Man', 'Woman', 'Prefer not to say',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Or, in your own words:'],
#       dtype='object')

# %%
# Q7.
plt.pie(gender_counts.values, labels = gender_counts.index, autopct = "%1.1f%%", startangle = 180, radius = 1.25)
plt.title(schema_raw.Gender)
# Out:
# Text(0.5, 1.0, 'Which of the following describe you, if any? Please check all that apply.')

# %%
schema_raw["EdLevel"]
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed? *'

# %%
survey_df["EdLevel"].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          30050
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15394
# Some college/university study without earning a degree                                 9194
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     7769
# Associate degree (A.A., A.S., etc.)                                                    2221
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2152
# Primary/elementary school                                                              1767
# Something else                                                                         1222
# Professional degree (JD, MD, etc.)                                                     1110
# Name: EdLevel, dtype: int64

# %%
# Q8.
plt.figure(figsize = (12, 6))
sns.countplot(y = survey_df["EdLevel"])
plt.title(schema_raw["EdLevel"])
plt.xticks(rotation = 45)
plt.ylabel(None)
plt.show()

# %%
# Q9.
EdLevel_pct = survey_df.EdLevel.value_counts(True) * 100
EdLevel_pct
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          42.396196
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       21.718704
# Some college/university study without earning a degree                                12.971402
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    10.960933
# Associate degree (A.A., A.S., etc.)                                                    3.133509
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             3.036160
# Primary/elementary school                                                              2.492981
# Something else                                                                         1.724065
# Professional degree (JD, MD, etc.)                                                     1.566049
# Name: EdLevel, dtype: float64

# %%
sns.barplot(x = EdLevel_pct, y = EdLevel_pct.index)
plt.title(schema_raw["EdLevel"])
plt.ylabel(None)
plt.xlabel("Percentage")
# Out:
# Text(0.5, 0, 'Percentage')

# %%
schema_raw["Employment"]
# Out:
# 'Which of the following best describes your current employment status?'

# %%
survey_df["Employment"].value_counts()
# Out:
# Employed, full-time                                                                                               42644
# Student, full-time                                                                                                 6663
# Independent contractor, freelancer, or self-employed                                                               4941
# Employed, full-time;Independent contractor, freelancer, or self-employed                                           3456
# Not employed, but looking for work                                                                                 1810
#                                                                                                                   ...
# Student, part-time;Independent contractor, freelancer, or self-employed;Retired                                       1
# Employed, full-time;Student, full-time;Student, part-time;Independent contractor, freelancer, or self-employed        1
# ...

# %%
# Q10.
employment = (survey_df.Employment.value_counts(True, ascending = False) * 100).head(15)
sns.barplot(x = employment, y = employment.index)
plt.title(schema_raw.Employment)
plt.xlabel("Percentage")
# Out:
# Text(0.5, 0, 'Percentage')

# %%
schema_raw.DevType
# Out:
# 'Which of the following describes your current job? Please select all that apply.'

# %%
survey_df.DevType.count()
# Out:
# 60761

# %%
survey_df.DevType.value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                  7091
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                    5274
# ...

# %%
# Q11.
survey_df["DevType"]
# Out:
# ResponseId
# 1                                                      NaN
# 2                                                      NaN
# 3        Data scientist or machine learning specialist;...
# 4                                    Developer, full-stack
# 5        Developer, front-end;Developer, full-stack;Dev...
#                                ...
# 73264                                  Developer, back-end
# 73265        Data scientist or machine learning specialist
# 73266    Developer, full-stack;Developer, desktop or en...
# 73267    Developer, front-end;Developer, desktop or ent...
# 73268    Developer, front-end;Engineer, data;Engineer, ...
# Name: DevType, Length: 73268, dtype: object

# %%
pd.DataFrame(survey_df["DevType"])
# Out:
#                                                       DevType
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Data scientist or machine learning specialist;...
# 4                                       Developer, full-stack
# 5           Developer, front-end;Developer, full-stack;Dev...
# ...                                                       ...
# 73264                                     Developer, back-end
# 73265           Data scientist or machine learning specialist
# 73266       Developer, full-stack;Developer, desktop or en...
# 73267       Developer, front-end;Developer, desktop or ent...
# 73268       Developer, front-end;Engineer, data;Engineer, ...
#
# [73268 rows x 1 columns]

# %%
dt = survey_df["DevType"]

# %%
for idx, value in dt.items():
    value.split(";")
    if idx > 10:
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9408\2748721492.py in <module>
#       1 for idx, value in dt.items():
# ----> 2     value.split(";")
#       3     if idx > 10:
#       4         break
#
# AttributeError: 'float' object has no attribute 'split'

# %%
type(np.nan)
# Out:
# float

# %% [markdown]
# NaN을 없애는 이유 -> float object는 split이 불가능(에러 발생 이유) 그런데 NaN은 자료형이 float

# %%
for idx, value in dt[dt.notnull()].items():
    print(value.split(";"))
    if idx > 10:
        break
# Out:
# ['Data scientist or machine learning specialist', 'Developer, front-end', 'Engineer, data', 'Engineer, site reliability']
# ['Developer, full-stack']
# ['Developer, front-end', 'Developer, full-stack', 'Developer, back-end', 'Developer, desktop or enterprise applications', 'Developer, QA or test']
# ['Developer, full-stack', 'Student']
# ['Developer, back-end']
# ['Developer, desktop or enterprise applications', 'Developer, mobile', 'Educator']
# ['Developer, full-stack', 'Developer, back-end']

# %% [markdown]
# 리스트 원소 하나하나가 columns 이름이 됨

# %%
for idx, value in col_series[col_series.notnull()].items():
    for option in value.split(";"):
        if option not in result_df.columns:
            options.append(option)
            result_df[option] = False
        result_df.at[idx, option] = True

# %%
################################################################################################################

# %%
### 3/16 진도

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()  # 반환할 Data frame
    options = []  # Column 이름을 담기 위해 만든 리스트
        
    for idx, value in col_series[col_series.notnull()].items():
        for option in value.split(";"):
            if option not in result_df.columns:  # result_df에 어떤 값이 없다면
                options.append(option)          # option이라는 List에 값을 추가하라
                result_df[option] = False      # 기존에 없던 값에 대한 새로운 열 추가 후 초기값 False로 설정
            result_df.at[idx, option] = True  # option 안에는 indexing이 가능한 열 이름만 존재하게 됨
                                             # 값이 존재하는 사람에 대해 True로 변환 (ex. 3번째 데싸~ 전문가)
    return result_df[options]

# 값이 존재하는 사람? -> indexing이 가능해짐으로써 result_df에 정보가 추가된 사람을 의미

# %%
dev_type_df = split_multicolumn(survey_df.DevType)
dev_type_df
# Out:
#             Data scientist or machine learning specialist  \
# ResponseId
# 1                                                   False
# 2                                                   False
# 3                                                    True
# 4                                                   False
# 5                                                   False
# ...                                                   ...
# 73264                                               False
# 73265                                                True
# 73266                                               False
# 73267                                               False
# 73268                                               False
#
#             Developer, front-end  Engineer, data  Engineer, site reliability  \
# ResponseId
# 1                          False           False                       False
# 2                          False           False                       False
# ...

# %%
# Q11 다른 풀이

# %%
def split_multicolumn(s):
    s.dropna(inplace=True) #결측치 제거
    df = pd.DataFrame(s) #데이터프레임화
    for x in s.str.split(';').items(): #인덱스와 ;를 기준으로 스플릿된 스트링 리스트 반환
        df.loc[x[0],x[1]]=True #해당 인덱스와 스트링 리스트의 요소인 칼럼에 대해 True값 설정
    df.fillna(False,inplace=True) #자동으로 NaN이 된 결측치 모두 False로 변환
    return df
    
split_multicolumn(survey_df.DevType)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9408\636048987.py in <module>
#       7     return df
#       8
# ----> 9 split_multicolumn(survey_df.DevType)
#
# ~\AppData\Local\Temp\ipykernel_9408\636048987.py in split_multicolumn(s)
#       3     df = pd.DataFrame(s) #데이터프레임화
#       4     for x in s.str.split(';').items(): #인덱스와 ;를 기준으로 스플릿된 스트링 리스트 반환
# ----> 5         df.loc[x[0],x[1]]=True #해당 인덱스와 스트링 리스트의 요소인 칼럼에 대해 True값 설정
#       6     df.fillna(False,inplace=True) #자동으로 NaN이 된 결측치 모두 False로 변환
#       7     return df
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     710         else:
#     711             key = com.apply_if_callable(key, self.obj)
# --> 712         indexer = self._get_setitem_indexer(key)
#     713         self._has_valid_setitem_indexer(key)
#     714
#
# ...

# %%
# Q12.
len(dev_type_df.columns)
# Out:
# 29

# %%
dev_type_df.astype(int).sum().nlargest(len(dev_type_df.columns))
# Out:
# Developer, full-stack                            28433
# Developer, back-end                              26369
# Developer, front-end                             15739
# Developer, desktop or enterprise applications     9451
# Developer, mobile                                 7566
# DevOps specialist                                 6093
# Student                                           5503
# Cloud infrastructure engineer                     5215
# Database administrator                            4872
# System administrator                              4828
# Developer, embedded applications or devices       3871
# Project manager                                   3844
# Designer                                          3712
# Engineer, data                                    3558
# Engineering manager                               3534
# Data scientist or machine learning specialist     3377
# Data or business analyst                          3166
# ...

# %%
# Q12 다른 풀이
dev_type_totals = dev_type_df.sum().sort_values(ascending = False)
dev_type_totals
# Out:
# Developer, full-stack                            28433
# Developer, back-end                              26369
# Developer, front-end                             15739
# Developer, desktop or enterprise applications     9451
# Developer, mobile                                 7566
# DevOps specialist                                 6093
# Student                                           5503
# Cloud infrastructure engineer                     5215
# Database administrator                            4872
# System administrator                              4828
# Developer, embedded applications or devices       3871
# Project manager                                   3844
# Designer                                          3712
# Engineer, data                                    3558
# Engineering manager                               3534
# Data scientist or machine learning specialist     3377
# Data or business analyst                          3166
# ...

# %%
# Q13.
percentage = (dev_type_df.sum().sort_values(ascending = False) / dev_type_df.sum().sum()) * 100
percentage
# Out:
# Developer, full-stack                            17.462842
# Developer, back-end                              16.195185
# Developer, front-end                              9.666503
# Developer, desktop or enterprise applications     5.804569
# Developer, mobile                                 4.646849
# DevOps specialist                                 3.742169
# Student                                           3.379806
# Cloud infrastructure engineer                     3.202923
# Database administrator                            2.992261
# System administrator                              2.965238
# Developer, embedded applications or devices       2.377472
# Project manager                                   2.360889
# Designer                                          2.279818
# Engineer, data                                    2.185235
# Engineering manager                               2.170495
# Data scientist or machine learning specialist     2.074070
# ...

# %%
sum(percentage)  # 100이 안나오는 것은 연산 과정에서 약간의 오차가 발생하기 때문
# Out:
# 99.99999999999999

# %%
# Q13 다른 풀이
devtype_percentage = dev_type_totals = dev_type_totals / dev_type_totals.sum() * 100
devtype_percentage

# 변수 지정 시 등호를 2번 이어서 써도 가능함
# Out:
# Developer, full-stack                            17.462842
# Developer, back-end                              16.195185
# Developer, front-end                              9.666503
# Developer, desktop or enterprise applications     5.804569
# Developer, mobile                                 4.646849
# DevOps specialist                                 3.742169
# Student                                           3.379806
# Cloud infrastructure engineer                     3.202923
# Database administrator                            2.992261
# System administrator                              2.965238
# Developer, embedded applications or devices       2.377472
# Project manager                                   2.360889
# Designer                                          2.279818
# Engineer, data                                    2.185235
# Engineering manager                               2.170495
# Data scientist or machine learning specialist     2.074070
# ...

# %%
# Q14.
plt.figure(figsize = (12, 12))
sns.barplot(x = devtype_percentage, y = devtype_percentage.index)
plt.title(schema_raw.DevType)
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# Q15. 2022년 가장 인기 있는 프로그래밍 언어?  -> Q11 함수 이용
survey_df.LanguageHaveWorkedWith
# Out:
# ResponseId
# 1                                                      NaN
# 2                                    JavaScript;TypeScript
# 3                        C#;C++;HTML/CSS;JavaScript;Python
# 4                             C#;JavaScript;SQL;TypeScript
# 5              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73264    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73267                                        C#;Delphi;VBA
# 73268          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
language_worked_df = split_multicolumn(survey_df.LanguageHaveWorkedWith)
language_worked_df
# Out:
#             JavaScript  TypeScript     C#    C++  HTML/CSS  Python    SQL  \
# ResponseId
# 1                False       False  False  False     False   False  False
# 2                 True        True  False  False     False   False  False
# 3                 True       False   True   True      True    True  False
# 4                 True        True   True  False     False   False   True
# 5                 True        True   True  False      True   False   True
# ...                ...         ...    ...    ...       ...     ...    ...
# 73264             True        True  False  False     False    True   True
# 73265             True       False  False  False      True    True   True
# 73266             True       False  False  False      True    True   True
# 73267            False       False   True  False     False   False  False
# 73268             True        True   True  False     False   False   True
#
# ...

# %%
Lw = language_worked_df.sum().sort_values(ascending = False)
Lw
# Out:
# JavaScript     45969
# HTML/CSS       38714
# SQL            34782
# Python         33772
# TypeScript     24470
# Java           23395
# Bash/Shell     20357
# C#             19672
# C++            15839
# PHP            14660
# C              13506
# PowerShell      8469
# Go              7823
# Rust            6483
# Kotlin          6416
# Dart            4592
# Ruby            4226
# Assembly        3796
# Swift           3444
# R               3261
# VBA             3147
# MATLAB          2869
# Lua             2802
# Groovy          2322
# Delphi          2287
# Scala           1799
# Objective-C     1668
# Perl            1611
# Haskell         1531
# Elixir          1497
# Julia           1059
# Clojure         1042
# Solidity        1008
# LISP             899
# F#               713
# Fortran          631
# Erlang           619
# APL              475
# COBOL            445
# SAS              417
# OCaml            402
# Crystal          324
# dtype: int64

# %%
(Lw / Lw.sum()) * 100
# Out:
# JavaScript     12.656210
# HTML/CSS       10.658759
# SQL             9.576199
# Python          9.298125
# TypeScript      6.737094
# Java            6.441124
# Bash/Shell      5.604700
# C#              5.416106
# C++             4.360802
# PHP             4.036199
# C               3.718479
# PowerShell      2.331690
# Go              2.153833
# Rust            1.784903
# Kotlin          1.766457
# Dart            1.264272
# Ruby            1.163505
# Assembly        1.045117
# Swift           0.948204
# R               0.897820
# VBA             0.866434
# MATLAB          0.789895
# Lua             0.771448
# Groovy          0.639294
# Delphi          0.629658
# Scala           0.495302
# Objective-C     0.459235
# Perl            0.443541
# Haskell         0.421516
# Elixir          0.412155
# Julia           0.291564
# Clojure         0.286884
# Solidity        0.277523
# LISP            0.247513
# F#              0.196304
# Fortran         0.173727
# Erlang          0.170423
# ...

# %%
plt.figure(figsize = (12, 12))
sns.barplot(x = (Lw / Lw.sum()) * 100, y = Lw.index)
plt.title("Languagues used in the past year")
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# Q16. - 사는 곳이 한국인 응답자의 기술 스텍 분포?
df_kor = survey_df[survey_df.Country == "South Korea"]
df_kor
# Out:
#                 Country              Age             Gender  \
# ResponseId
# 1289        South Korea  25-34 years old  Prefer not to say
# 2991        South Korea  25-34 years old                Man
# 3024        South Korea  25-34 years old                Man
# 3161        South Korea  18-24 years old                Man
# 3351        South Korea  18-24 years old                Man
# ...                 ...              ...                ...
# 70938       South Korea  18-24 years old                Man
# 70985       South Korea  45-54 years old              Woman
# 71427       South Korea  25-34 years old                Man
# 72244       South Korea  25-34 years old                Man
# 73026       South Korea  35-44 years old                Man
#
#                                                       EdLevel  YearsCode  \
# ResponseId
# 1289             Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0
# ...

# %%
lan_kor_df = split_multicolumn(df_kor.LanguageHaveWorkedWith)
lan_kor_df
# Out:
#              Rust    C++  HTML/CSS  JavaScript  Python  Bash/Shell     Go  \
# ResponseId
# 1289         True  False     False       False   False       False  False
# 2991        False   True      True        True    True       False  False
# 3024        False  False     False        True   False        True   True
# 3161         True  False     False        True   False       False   True
# 3351        False  False      True        True   False       False  False
# ...           ...    ...       ...         ...     ...         ...    ...
# 70938        True   True      True        True   False        True  False
# 70985       False   True      True        True    True       False  False
# 71427       False  False     False       False   False       False  False
# 72244       False   True      True        True   False        True  False
# 73026       False  False     False       False   False       False  False
#
# ...

# %%
kor_ser = lan_kor_df.sum().sort_values(ascending = False)
kor_ser
# Out:
# JavaScript     144
# Python         116
# HTML/CSS       106
# Java            98
# SQL             84
# TypeScript      80
# C++             69
# Bash/Shell      58
# C               53
# C#              47
# Kotlin          39
# Go              25
# PHP             22
# Swift           18
# Rust            18
# PowerShell      15
# Dart            14
# R               10
# MATLAB          10
# Objective-C     10
# Assembly         9
# Ruby             8
# VBA              6
# Groovy           5
# Delphi           5
# Haskell          5
# Elixir           5
# Scala            4
# OCaml            4
# Julia            4
# Lua              4
# Clojure          3
# LISP             3
# Solidity         3
# F#               3
# SAS              3
# COBOL            2
# APL              2
# Erlang           2
# Perl             2
# Crystal          1
# Fortran          1
# dtype: int64

# %%
plt.figure(figsize = (12, 12))
sns.barplot(x = (kor_ser / kor_ser.sum()) * 100, y = kor_ser.index)
plt.title("Languagues used in the past year in South Korea")
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# Q16-1
df_kor2 = survey_df[(survey_df.Country == "South Korea") | (survey_df.Country == "Republic of Korea")]
df_kor2
# Out:
#                       Country              Age             Gender  \
# ResponseId
# 1289              South Korea  25-34 years old  Prefer not to say
# 2933        Republic of Korea  35-44 years old                Man
# 2991              South Korea  25-34 years old                Man
# 3024              South Korea  25-34 years old                Man
# 3161              South Korea  18-24 years old                Man
# ...                       ...              ...                ...
# 70985             South Korea  45-54 years old              Woman
# 71427             South Korea  25-34 years old                Man
# 72114       Republic of Korea  25-34 years old                Man
# 72244             South Korea  25-34 years old                Man
# 73026             South Korea  35-44 years old                Man
#
#                                                       EdLevel  YearsCode  \
# ResponseId
# 1289             Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0
# ...

# %%
lan_kor_df2 = split_multicolumn(df_kor2.LanguageHaveWorkedWith)
lan_kor_df2
# Out:
#              Rust  Python    C++  HTML/CSS  JavaScript  Bash/Shell     Go  \
# ResponseId
# 1289         True   False  False     False       False       False  False
# 2933         True    True  False     False       False       False  False
# 2991        False    True   True      True        True       False  False
# 3024        False   False  False     False        True        True   True
# 3161         True   False  False     False        True       False   True
# ...           ...     ...    ...       ...         ...         ...    ...
# 70985       False    True   True      True        True       False  False
# 71427       False   False  False     False       False       False  False
# 72114       False    True  False     False       False       False  False
# 72244       False   False   True      True        True        True  False
# 73026       False   False  False     False       False       False  False
#
# ...

# %%
kor_ser2 = lan_kor_df2.sum().sort_values(ascending = False)
kor_ser2
# Out:
# JavaScript     188
# Python         152
# HTML/CSS       137
# Java           125
# SQL            109
# TypeScript     101
# C++             87
# C               72
# Bash/Shell      72
# C#              62
# Kotlin          54
# Go              34
# PHP             33
# PowerShell      25
# Rust            24
# Swift           23
# Dart            18
# Assembly        15
# R               14
# Ruby            12
# MATLAB          11
# Objective-C     10
# Lua              8
# Groovy           8
# VBA              7
# Elixir           7
# Scala            7
# Haskell          7
# Julia            6
# Delphi           5
# Solidity         4
# OCaml            4
# Perl             4
# LISP             3
# SAS              3
# Clojure          3
# F#               3
# APL              2
# COBOL            2
# Erlang           2
# Crystal          1
# Fortran          1
# dtype: int64

# %%
plt.figure(figsize = (12, 12))
sns.barplot(x = (kor_ser2 / kor_ser2.sum()) * 100, y = kor_ser2.index)
plt.title("Languagues used in the past year in South Korea")
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# Q17. - 데싸 관련 분야에서 일하는 응답자들이 가장 많이 사용하는 언어?
df_Dsml = survey_df[survey_df.DevType == "Data scientist or machine learning specialist"]
df_Dsml
# Out:
#                                                       Country  \
# ResponseId
# 464                                                    Israel
# 1090        United Kingdom of Great Britain and Northern I...
# 1705                                 United States of America
# 1708                                 United States of America
# 1871                                              Netherlands
# ...                                                       ...
# 72707                                            South Africa
# 72793                                               Lithuania
# 73045                                                Viet Nam
# 73065                                                 Romania
# 73265                                United States of America
#
#                         Age Gender  \
# ResponseId
# 464         25-34 years old    Man
# 1090        25-34 years old    Man
# 1705        35-44 years old    Man
# 1708        18-24 years old    Man
# ...

# %%
df_lan_Dsml = split_multicolumn(df_Dsml.LanguageHaveWorkedWith)
df_lan_Dsml
# Out:
#             Bash/Shell  Python    SQL  Elixir   Rust  TypeScript     Go  \
# ResponseId
# 464               True    True   True   False  False       False  False
# 1090             False    True  False   False  False       False  False
# 1705             False    True   True    True   True        True  False
# 1708             False    True  False   False  False       False  False
# 1871              True    True  False   False  False       False   True
# ...                ...     ...    ...     ...    ...         ...    ...
# 72707            False   False   True   False  False       False  False
# 72793             True    True  False   False  False       False  False
# 73045            False    True  False   False  False       False  False
# 73065            False    True   True   False  False       False  False
# 73265             True    True   True   False  False       False  False
#
#             HTML/CSS  Assembly      C    C++   Java  JavaScript  Julia      R  \
# ...

# %%
Dsml = df_lan_Dsml.sum().nlargest(len(df_lan_Dsml.columns))
Dsml
# Out:
# Python         463
# SQL            270
# R              141
# Bash/Shell     140
# JavaScript     109
# HTML/CSS        93
# C++             91
# Java            59
# C               52
# Julia           32
# PowerShell      31
# MATLAB          31
# TypeScript      28
# C#              27
# SAS             23
# Scala           22
# Go              19
# Rust            19
# VBA             14
# Swift            8
# Lua              8
# Dart             8
# Haskell          7
# Assembly         7
# PHP              7
# LISP             6
# Kotlin           5
# Perl             5
# Ruby             5
# Objective-C      5
# Clojure          3
# Elixir           2
# Groovy           2
# Solidity         2
# Fortran          2
# Delphi           2
# COBOL            1
# APL              1
# OCaml            1
# F#               1
# dtype: int64

# %%
(Dsml / Dsml.sum()) * 100
# Out:
# Python         26.426941
# SQL            15.410959
# R               8.047945
# Bash/Shell      7.990868
# JavaScript      6.221461
# HTML/CSS        5.308219
# C++             5.194064
# Java            3.367580
# C               2.968037
# Julia           1.826484
# PowerShell      1.769406
# MATLAB          1.769406
# TypeScript      1.598174
# C#              1.541096
# SAS             1.312785
# Scala           1.255708
# Go              1.084475
# Rust            1.084475
# VBA             0.799087
# Swift           0.456621
# Lua             0.456621
# Dart            0.456621
# Haskell         0.399543
# Assembly        0.399543
# PHP             0.399543
# LISP            0.342466
# Kotlin          0.285388
# Perl            0.285388
# Ruby            0.285388
# Objective-C     0.285388
# Clojure         0.171233
# Elixir          0.114155
# Groovy          0.114155
# Solidity        0.114155
# Fortran         0.114155
# Delphi          0.114155
# COBOL           0.057078
# ...

# %%
sns.barplot(x = (Dsml / Dsml.sum()) * 100, y = Dsml.index)
plt.title("Languagues used by Data Scientists or Machine Learning Folks")
plt.xlabel("Percentage")
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
# 다른 문제는 혼자서 풀어보기
